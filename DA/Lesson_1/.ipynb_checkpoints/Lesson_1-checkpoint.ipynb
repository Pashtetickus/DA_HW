# %% [markdown]
# Семинар 1 (неделя 2)
# =====
#
# Описательные статистики
# ----

# %%
# Импорт библиотек
import pandas as pd
import numpy as np


# Чтение файла данных с помощью pandas
RWQ = pd.read_csv('winequality-red.csv', sep=";")

# Демонстрация первых 5 строк таблицы
RWQ.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# 1 - фиксированная кислотность;
# 2 - летучая кислотность;
# 3 - лимонная кислота;
# 4 - остаточный сахар;
# 5 - хлориды;
# 6 - свободный диоксид серы;
# 7 - диоксид серы общий;
# 8 - плотность;
# 9 - pH;
# 10 - сульфаты;
# 11 - алкоголь;
# 12 - качество (оценка от 0 до 10)
#
#
# Получим статистические характеристики параметров с помощью numpy:

# %%
RWQ.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# Чтение имен параметров из первой строки
with open('winequality-red.csv') as infile:
	names = infile.readline().rstrip('\n').split(';')

# Чтение данных без первой строки
data = np.loadtxt('winequality-red.csv', skiprows = 1, delimiter=';')

# Вывод параметров и их характеристик
for n in range(0, len(names)):
	print('\n' + names[n])
	print('\tmin\t{:.3f}'.format(np.min(data[:, n])))
	print('\tmean\t{:.3f}'.format(np.mean(data[:, n])))
	print('\tmax\t{:.3f}'.format(np.max(data[:, n])))
	print('\tStDev\t{:.3f}'.format(np.std(data[:, n])))
# Out:
# "fixed acidity"
# 	min	4.600
# 	mean	8.320
# 	max	15.900
# 	StDev	1.741
#
# "volatile acidity"
# 	min	0.120
# 	mean	0.528
# 	max	1.580
# 	StDev	0.179
#
# "citric acid"
# 	min	0.000
# 	mean	0.271
# 	max	1.000
# 	StDev	0.195
#
# "residual sugar"
# 	min	0.900
# 	mean	2.539
# 	max	15.500
# 	StDev	1.409
#
# "chlorides"
# 	min	0.012
# 	mean	0.087
# 	max	0.611
# 	StDev	0.047
#
# "free sulfur dioxide"
# 	min	1.000
# 	mean	15.875
# 	max	72.000
# 	StDev	10.457
#
# "total sulfur dioxide"
# 	min	6.000
# 	mean	46.468
# 	max	289.000
# 	StDev	32.885
#
# "density"
# 	min	0.990
# 	mean	0.997
# 	max	1.004
# 	StDev	0.002
#
# "pH"
# 	min	2.740
# 	mean	3.311
# 	max	4.010
# 	StDev	0.154
#
# "sulphates"
# 	min	0.330
# 	mean	0.658
# 	max	2.000
# 	StDev	0.169
#
# "alcohol"
# 	min	8.400
# 	mean	10.423
# 	max	14.900
# 	StDev	1.065
#
# "quality"
# 	min	3.000
# 	mean	5.636
# 	max	8.000
# 	StDev	0.807

# %% [markdown]
# Описательная статистика с помощью pandas:

# %%
RWQ.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Показать процентили заданного уровня
RWQ.describe(percentiles=[0.2, 0.9])
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 20%         7.000000          0.370000     0.070000        1.800000
# 50%         7.900000          0.520000     0.260000        2.200000
# 90%        10.700000          0.745000     0.522000        3.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Транспонированный вид
RWQ.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
# Вывод отдельных характеристик
RWQ['fixed acidity'].std()
# Out:
# 1.7410963181277006

# %% [markdown]
# Гистограммы
# -----
#
# Построим гистограммы для нескольких параметров:

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use('classic')

# %matplotlib inline


RWQ['pH'].hist(bins=20);

# %%
RWQ['citric acid'].hist(bins=30);

# %%
#plt.xscale('log')
RWQ['total sulfur dioxide'].hist(bins=20);

# %%
# Логарифмируем для перехода к нормальному распределению
np.log(RWQ['total sulfur dioxide']).hist(bins=20);

# %%
RWQ.groupby('quality').median()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                 7.50             0.845        0.035             2.1
# 4                 7.50             0.670        0.090             2.1
# 5                 7.80             0.580        0.230             2.2
# 6                 7.90             0.490        0.260             2.2
# 7                 8.80             0.370        0.400             2.3
# 8                 8.25             0.370        0.420             2.1
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density    pH  \
# quality
# 3           0.0905                  6.0                  15.0  0.997565  3.39
# 4           0.0800                 11.0                  26.0  0.996500  3.37
# 5           0.0810                 15.0                  47.0  0.997000  3.30
# 6           0.0780                 14.0                  35.0  0.996560  3.32
# ...

# %%
RWQ.groupby("quality").pH.mean()
# Out:
# quality
# 3    3.398000
# 4    3.381509
# 5    3.304949
# 6    3.318072
# 7    3.290754
# 8    3.267222
# Name: pH, dtype: float64

# %% [markdown]
# Ящики с усами
# -----

# %%
from IPython.display import Image
Image('boxplot_explanation.png')

# %%
ax = RWQ.boxplot(column = 'total sulfur dioxide', by = 'quality')
ax.get_figure().suptitle('')    #исправляем наезжающие заголовки графика
matplotlib.style.use('classic')

# %%
RWQ[RWQ['quality'] == 5]['total sulfur dioxide'].median()
# Out:
# 47.0

# %% [markdown]
# Предельная ошибка выборки
# -----

# %%
Image('Sample.png')

# %%
# Размерность таблицы
RWQ.shape
# Out:
# (1599, 12)

# %%
# Генерация набора индексов для выборки
sample = np.random.randint(1600, size = 160)
sample
# Out:
# array([1554,  626, 1523,  677,  566,  408,  650, 1154, 1414,  571,  759,
#         223, 1088,  522, 1239,  853,  682, 1236,   63,  858,  251,  732,
#        1539,  713,  536, 1534,  158, 1011,  370,  654,  225,  419, 1491,
#         579,   61, 1469,  304, 1202, 1334,  635, 1312,  347,  288,  847,
#         577, 1167,   23, 1307,   82,  553,  446,  607,  853, 1328, 1099,
#         206,  881,  394,  608, 1141,  882,  366,  519,  593,  129,  783,
#         131, 1093,  916,  284,  976,  765,  203,  348,  884,  308, 1074,
#         523, 1575,   94, 1594,  350,   62,  340,  223,   66, 1448,   60,
#         195, 1243,  563,  441,  334, 1044, 1242,  752, 1418,  960, 1270,
#         711,  951,  487, 1011,  614,  156,  414,  541, 1336,   77, 1244,
#         212,  559, 1148,  831,  149, 1300,  231,  923, 1165,  381, 1330,
#        1521,  920, 1121, 1587,  927,  425,  450,  428, 1325,  169,   65,
#        1070,  616, 1328,  605,   36, 1524,  299,  272,  924,  957,  317,
# ...

# %%
# Создание выборки
RWQ['total sulfur dioxide'][sample]
# Out:
# 1554     23.0
# 626      15.0
# 1523     61.0
# 677      31.0
# 566      15.0
#         ...
# 1181     11.0
# 805      10.0
# 219     144.0
# 134      29.0
# 790      82.0
# Name: total sulfur dioxide, Length: 160, dtype: float64

# %%
sample_ch = np.random.choice(RWQ['total sulfur dioxide'], 160, replace = False)
sample_ch
# Out:
# array([ 15.,  35.,  17.,  17.,  14.,  12.,  21.,  14.,  88., 145.,  57.,
#         55.,  34.,  65.,  51.,  30.,  38.,  53.,  45.,  32.,  35.,  25.,
#        112.,  11.,  11.,  58.,  53.,  37.,  50.,  28.,  88.,  22.,  93.,
#         14.,  14.,  65.,  94.,  77.,  53.,  88.,  61.,  47., 127.,  31.,
#         35.,  72.,  16.,  15.,  31.,  35., 135.,  25.,  28.,  35.,  40.,
#         12.,  94.,  17.,  10.,  21.,  39.,  34.,  42.,  37.,  49.,  85.,
#         48.,  86., 119.,  82.,  31.,  35.,  81.,  19., 145.,  52.,  89.,
#         29., 142.,  68., 102.,  29.,  27.,  38.,  58., 112., 139.,  25.,
#         31.,   9.,  38.,  85.,  22.,  25.,  17.,  22.,  39.,  28.,  38.,
#         10.,  26.,  53.,  11.,  85.,  43.,  10.,  22.,  73.,  54.,  53.,
#         85.,  95.,  38.,  44.,  46.,  54.,  46.,  55.,  42.,  25.,  38.,
#         65.,  16.,  87.,  25.,  40.,  25.,  32.,   8.,  31.,  48.,  86.,
#         11.,  71.,  30.,  76.,  27.,  32.,  39.,  37.,  23.,  12.,  20.,
# ...

# %%
# Среднее по выборке первым способом
RWQ['total sulfur dioxide'][sample].mean()
# Out:
# 47.93125

# %%
# Среднее по выборке вторым способом
np.mean(sample_ch)
# Out:
# 45.54375

# %%
# Среднее по генеральной совокупности
RWQ['total sulfur dioxide'].mean()
# Out:
# 46.46779237023139

# %%
# Расчёт предельной ошибки

tS = 1.96    # Для доверительного интервала 95%
std = RWQ['total sulfur dioxide'][sample].std()
N_g = 1599
n_s = 160

Dx = tS * np.sqrt( std**2 * (1 - n_s/N_g) / n_s )
Dx
# Out:
# 4.484382171722194

# %%
Image('Variance.png')

# %%
# Ручной расчёт дисперсии
Xi = RWQ['total sulfur dioxide'][sample]
Xm = RWQ['total sulfur dioxide'][sample].mean()
S2 = np.sum(np.power(Xi - Xm, 2))/(n_s - 1)
S2
# Out:
# 930.6807783018866

# %%
# Дисперсия из pandas
std**2
# Out:
# 930.6807783018866

# %% [markdown]
# Объём выборки
# -----

# %%
RWQ['total sulfur dioxide'].describe()
# Out:
# count    1599.000000
# mean       46.467792
# std        32.895324
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
# %matplotlib inline
RWQ['total sulfur dioxide'].hist(bins=20);

# %%
# Задаём предельную ошибку и находим необходимый объём выборки
tS = 2.58 # 99%
dx = 3.5
V_sample = tS**2 * std**2 * N_g / (dx**2 * N_g + tS**2 * std**2)
V_sample
# Out:
# 384.2020341330425

# %%
RWQ['total sulfur dioxide'].sample(n = 412).mean()
# Out:
# 44.536407766990294

# %% [markdown]
# Столбчатая диаграмма
# -----

# %%
import seaborn as sns

sns.catplot('quality', data = RWQ, kind = 'count')
# Out:
# /home/vladisgorm/miniconda3/envs/data/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
RWQ['quality'].hist();

# %% [markdown]
# Облако рассеивания
# -----

# %%
columns = ['free sulfur dioxide', 'total sulfur dioxide', 'chlorides', 'sulphates']
sns.pairplot(RWQ[columns], height=3, aspect=1);
